# %% [markdown]
# # Import respective Libraries

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("lung_cancer.csv")
df
# Out:
#      PATIENT_ID GENOMIC SEX AGE BLOOD_TYPE  NUMBER_OF_SIBLINGS  YEAR_OF_BIRTH  \
# 0        A10230           M  69          A                 5.0         1945.0
# 1        A10231           M  74          B                 1.0         1940.0
# 2        A10232           F  59         AB                 0.0         1955.0
# 3        A10233           M  63          O                 3.0         1951.0
# 4        A10234           F  63          A                 4.0         1951.0
# ...         ...         ...  ..        ...                 ...            ...
# 1115     A11345      FEMALE  57          A                 3.0         1957.0
# 1116     A11346      FEMALE  51          A                 2.0         1963.0
# 1117     A11347      FEMALE  65          A                 1.0         1949.0
# 1118     A11348      FEMALE  57          A                 2.0         1957.0
# 1119     A11349      FEMALE  20          A                 1.0         1994.0
#
# ...

# %% [markdown]
# # Check the null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PATIENT_ID             1120 non-null   object
#  1   GENOMIC SEX            1101 non-null   object
#  2   AGE                    1117 non-null   object
#  3   BLOOD_TYPE             1120 non-null   object
#  4   NUMBER_OF_SIBLINGS     1114 non-null   float64
#  5   YEAR_OF_BIRTH          1119 non-null   float64
#  6   ADOPTED_STATUS         1120 non-null   int64
#  7   NUMBER_OF_PREGNANCIES  546 non-null    float64
#  8   MONTH_OF_BIRTH         1120 non-null   int64
#  9   PARENT_ALIVE           1120 non-null   int64
#  10  SMOKING_STATUS         1120 non-null   int64
#  11  DAILY_CIGARETTES       617 non-null    object
#  12  YELLOW_SKIN            1120 non-null   int64
#  13  ANXIETY                1120 non-null   int64
# ...

# %% [markdown]
# # Drop the unwanted columns

# %%
# List of columns to drop
columns_to_drop = ['PATIENT_ID','ADOPTED_STATUS','NUMBER_OF_PREGNANCIES','MONTH_OF_BIRTH','YEAR_OF_BIRTH','Constant_Exhaustion']

# Filter out columns that are not in the DataFrame
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# Drop the existing columns
df.drop(existing_columns_to_drop, axis=1, inplace=True)

# %%
df['GENOMIC SEX'] = df['GENOMIC SEX'].str.replace('FEMALE','F',regex=True)
df['GENOMIC SEX'] = df['GENOMIC SEX'].str.replace('MALE','M',regex=True)

# %%
df
# Out:
#      GENOMIC SEX AGE BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0              M  69          A                 5.0             3
# 1              M  74          B                 1.0             2
# 2              F  59         AB                 0.0             2
# 3              M  63          O                 3.0             2
# 4              F  63          A                 4.0             1
# ...          ...  ..        ...                 ...           ...
# 1115           F  57          A                 3.0             3
# 1116           F  51          A                 2.0             2
# 1117           F  65          A                 1.0             1
# 1118           F  57          A                 2.0             1
# 1119           F  20          A                 1.0             1
#
#       SMOKING_STATUS DAILY_CIGARETTES  YELLOW_SKIN  ANXIETY  PEER_PRESSURE  \
# 0                  1              NaN            2        2              1
# ...

# %%
# Define mappings
sex_mapping = {'M': 1, 'F': 0}
blood_type_mapping = {'A': 0, 'B': 1, 'AB': 2, 'O': 3}
yes_no_mapping = {'YES': 2, 'NO': 1}

# Apply mappings
df['GENOMIC SEX'] = df['GENOMIC SEX'].map(sex_mapping)
df['BLOOD_TYPE'] = df['BLOOD_TYPE'].map(blood_type_mapping)
#df['Constant_Exhaustion'] = df['Constant_Exhaustion'].map(yes_no_mapping)
df['LUNG_CANCER'] = df['LUNG_CANCER'].map(yes_no_mapping)

# %%
df
# Out:
#       GENOMIC SEX AGE  BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0             1.0  69         0.0                 5.0             3
# 1             1.0  74         1.0                 1.0             2
# 2             0.0  59         2.0                 0.0             2
# 3             1.0  63         3.0                 3.0             2
# 4             0.0  63         0.0                 4.0             1
# ...           ...  ..         ...                 ...           ...
# 1115          0.0  57         0.0                 3.0             3
# 1116          0.0  51         0.0                 2.0             2
# 1117          0.0  65         0.0                 1.0             1
# 1118          0.0  57         0.0                 2.0             1
# 1119          0.0  20         0.0                 1.0             1
#
#       SMOKING_STATUS DAILY_CIGARETTES  YELLOW_SKIN  ANXIETY  PEER_PRESSURE  \
# ...

# %% [markdown]
# # Categorical to numerical

# %%
# Convert columns to numeric
df['DAILY_CIGARETTES'] = pd.to_numeric(df['DAILY_CIGARETTES'], errors='coerce')
df['COPD_DIAGNOSES'] = pd.to_numeric(df['COPD_DIAGNOSES'], errors='coerce')
df['WHEEZING'] = pd.to_numeric(df['WHEEZING'], errors='coerce')
df['SHORTNESS_OF_BREATH'] = pd.to_numeric(df['SHORTNESS_OF_BREATH'], errors='coerce')

# %% [markdown]
# # Missing values filling

# %%
# Fill missing values
df['DAILY_CIGARETTES'].fillna(df['DAILY_CIGARETTES'].median(), inplace=True)
df['COPD_DIAGNOSES'].fillna(df['COPD_DIAGNOSES'].median(), inplace=True)
df['WHEEZING'].fillna(df['WHEEZING'].median(), inplace=True)
df['SHORTNESS_OF_BREATH'].fillna(df['SHORTNESS_OF_BREATH'].median(), inplace=True)
# Out:
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\2443190508.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DAILY_CIGARETTES'].fillna(df['DAILY_CIGARETTES'].median(), inplace=True)
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\2443190508.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df
# Out:
#       GENOMIC SEX AGE  BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0             1.0  69         0.0                 5.0             3
# 1             1.0  74         1.0                 1.0             2
# 2             0.0  59         2.0                 0.0             2
# 3             1.0  63         3.0                 3.0             2
# 4             0.0  63         0.0                 4.0             1
# ...           ...  ..         ...                 ...           ...
# 1115          0.0  57         0.0                 3.0             3
# 1116          0.0  51         0.0                 2.0             2
# 1117          0.0  65         0.0                 1.0             1
# 1118          0.0  57         0.0                 2.0             1
# 1119          0.0  20         0.0                 1.0             1
#
#       SMOKING_STATUS  DAILY_CIGARETTES  YELLOW_SKIN  ANXIETY  PEER_PRESSURE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENOMIC SEX            1101 non-null   float64
#  1   AGE                    1117 non-null   object
#  2   BLOOD_TYPE             1117 non-null   float64
#  3   NUMBER_OF_SIBLINGS     1114 non-null   float64
#  4   PARENT_ALIVE           1120 non-null   int64
#  5   SMOKING_STATUS         1120 non-null   int64
#  6   DAILY_CIGARETTES       1120 non-null   float64
#  7   YELLOW_SKIN            1120 non-null   int64
#  8   ANXIETY                1120 non-null   int64
#  9   PEER_PRESSURE          1120 non-null   int64
#  10  COPD_DIAGNOSES         1120 non-null   float64
#  11  FATIGUE                1115 non-null   float64
#  12  ALLERGY                1120 non-null   int64
#  13  WHEEZING               1120 non-null   float64
# ...

# %%
df['NUMBER_OF_SIBLINGS'].fillna(0,inplace=True)
# Out:
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\3702151541.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NUMBER_OF_SIBLINGS'].fillna(0,inplace=True)

# %%
# Step 1: Convert non-numeric values to NaN
df['AGE'] = pd.to_numeric(df['AGE'], errors='coerce')

# Step 2: Calculate the mean of the 'AGE' column, excluding NaN values
mean_age = df['AGE'].mean()

# Step 3: Fill NaN values with the mean_age
df['AGE'].fillna(mean_age, inplace=True)

# Step 4: Convert the 'AGE' column to integer type
df['AGE'] = df['AGE'].astype(int)
# Out:
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\1613077543.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AGE'].fillna(mean_age, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENOMIC SEX            1101 non-null   float64
#  1   AGE                    1120 non-null   int32
#  2   BLOOD_TYPE             1117 non-null   float64
#  3   NUMBER_OF_SIBLINGS     1120 non-null   float64
#  4   PARENT_ALIVE           1120 non-null   int64
#  5   SMOKING_STATUS         1120 non-null   int64
#  6   DAILY_CIGARETTES       1120 non-null   float64
#  7   YELLOW_SKIN            1120 non-null   int64
#  8   ANXIETY                1120 non-null   int64
#  9   PEER_PRESSURE          1120 non-null   int64
#  10  COPD_DIAGNOSES         1120 non-null   float64
#  11  FATIGUE                1115 non-null   float64
#  12  ALLERGY                1120 non-null   int64
#  13  WHEEZING               1120 non-null   float64
# ...

# %%
df
# Out:
#       GENOMIC SEX  AGE  BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0             1.0   69         0.0                 5.0             3
# 1             1.0   74         1.0                 1.0             2
# 2             0.0   59         2.0                 0.0             2
# 3             1.0   63         3.0                 3.0             2
# 4             0.0   63         0.0                 4.0             1
# ...           ...  ...         ...                 ...           ...
# 1115          0.0   57         0.0                 3.0             3
# 1116          0.0   51         0.0                 2.0             2
# 1117          0.0   65         0.0                 1.0             1
# 1118          0.0   57         0.0                 2.0             1
# 1119          0.0   20         0.0                 1.0             1
#
#       SMOKING_STATUS  DAILY_CIGARETTES  YELLOW_SKIN  ANXIETY  PEER_PRESSURE  \
# ...

# %%
# Handle missing values in 'BLOOD_TYPE'
# Option 1: Fill missing values with a specific value or use a placeholder
df['BLOOD_TYPE'].fillna(0, inplace=True)

# Option 2: Convert 'BLOOD_TYPE' to categorical
df['BLOOD_TYPE'] = df['BLOOD_TYPE'].astype('object')

# Handle missing values in 'LUNG_CANCER'
# Option 1: Fill with a placeholder or mode
df['LUNG_CANCER'].fillna(0, inplace=True)

# Convert 'LUNG_CANCER' to categorical
df['LUNG_CANCER'] = df['LUNG_CANCER'].astype('object')
# Out:
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\474474361.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BLOOD_TYPE'].fillna(0, inplace=True)
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\474474361.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENOMIC SEX            1101 non-null   float64
#  1   AGE                    1120 non-null   int32
#  2   BLOOD_TYPE             1120 non-null   object
#  3   NUMBER_OF_SIBLINGS     1120 non-null   float64
#  4   PARENT_ALIVE           1120 non-null   int64
#  5   SMOKING_STATUS         1120 non-null   int64
#  6   DAILY_CIGARETTES       1120 non-null   float64
#  7   YELLOW_SKIN            1120 non-null   int64
#  8   ANXIETY                1120 non-null   int64
#  9   PEER_PRESSURE          1120 non-null   int64
#  10  COPD_DIAGNOSES         1120 non-null   float64
#  11  FATIGUE                1115 non-null   float64
#  12  ALLERGY                1120 non-null   int64
#  13  WHEEZING               1120 non-null   float64
# ...

# %%
# Find the mode of the 'GENOMIC SEX' column
mode_genomic_sex = df['GENOMIC SEX'].mode()[0]

# Fill missing values with the mode
df['GENOMIC SEX'].fillna(mode_genomic_sex, inplace=True)

# Option 2: Convert 'BLOOD_TYPE' to categorical
df['GENOMIC SEX'] = df['GENOMIC SEX'].astype('object')
# Out:
# C:\Users\Vergeena\AppData\Local\Temp\ipykernel_2260\3174264232.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GENOMIC SEX'].fillna(mode_genomic_sex, inplace=True)

# %%
# Print current columns to verify
print("Columns in DataFrame:", df.columns)

# Trim any leading or trailing spaces from column names
df.columns = df.columns.str.strip()

# Verify the updated column names
print("Updated Columns in DataFrame:", df.columns)

# Fill missing values in 'FATIGUE' column
df['FATIGUE'].fillna(0, inplace=True)

# Print DataFrame to see changes
print("Updated DataFrame:")
print(df)
# Out:
# Columns in DataFrame: Index(['GENOMIC SEX', 'AGE', 'BLOOD_TYPE', 'NUMBER_OF_SIBLINGS',
#        'PARENT_ALIVE', 'SMOKING_STATUS', 'DAILY_CIGARETTES', 'YELLOW_SKIN',
#        'ANXIETY', 'PEER_PRESSURE', 'COPD_DIAGNOSES', 'FATIGUE ', 'ALLERGY ',
#        'WHEEZING', 'ALCOHOL_CONSUMPTION', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')
# Updated Columns in DataFrame: Index(['GENOMIC SEX', 'AGE', 'BLOOD_TYPE', 'NUMBER_OF_SIBLINGS',
#        'PARENT_ALIVE', 'SMOKING_STATUS', 'DAILY_CIGARETTES', 'YELLOW_SKIN',
#        'ANXIETY', 'PEER_PRESSURE', 'COPD_DIAGNOSES', 'FATIGUE', 'ALLERGY',
#        'WHEEZING', 'ALCOHOL_CONSUMPTION', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')
# Updated DataFrame:
#      GENOMIC SEX  AGE BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0            1.0   69        0.0                 5.0             3
# ...

# %%
df.columns
# Out:
# Index(['GENOMIC SEX', 'AGE', 'BLOOD_TYPE', 'NUMBER_OF_SIBLINGS',
#        'PARENT_ALIVE', 'SMOKING_STATUS', 'DAILY_CIGARETTES', 'YELLOW_SKIN',
#        'ANXIETY', 'PEER_PRESSURE', 'COPD_DIAGNOSES', 'FATIGUE', 'ALLERGY',
#        'WHEEZING', 'ALCOHOL_CONSUMPTION', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
independent=df[['GENOMIC SEX','AGE','BLOOD_TYPE','NUMBER_OF_SIBLINGS','PARENT_ALIVE','SMOKING_STATUS','DAILY_CIGARETTES',
                'YELLOW_SKIN','ANXIETY','PEER_PRESSURE','COPD_DIAGNOSES','FATIGUE','WHEEZING','ALCOHOL_CONSUMPTION',
                'COUGHING','SHORTNESS_OF_BREATH','SWALLOWING_DIFFICULTY','CHEST_PAIN']]
independent
# Out:
#      GENOMIC SEX  AGE BLOOD_TYPE  NUMBER_OF_SIBLINGS  PARENT_ALIVE  \
# 0            1.0   69        0.0                 5.0             3
# 1            1.0   74        1.0                 1.0             2
# 2            0.0   59        2.0                 0.0             2
# 3            1.0   63        3.0                 3.0             2
# 4            0.0   63        0.0                 4.0             1
# ...          ...  ...        ...                 ...           ...
# 1115         0.0   57        0.0                 3.0             3
# 1116         0.0   51        0.0                 2.0             2
# 1117         0.0   65        0.0                 1.0             1
# 1118         0.0   57        0.0                 2.0             1
# 1119         0.0   20        0.0                 1.0             1
#
#       SMOKING_STATUS  DAILY_CIGARETTES  YELLOW_SKIN  ANXIETY  PEER_PRESSURE  \
# 0                  1              17.0            2        2              1
# ...

# %%
dependent=df[['LUNG_CANCER']]
dependent
# Out:
#      LUNG_CANCER
# 0            2.0
# 1            2.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...          ...
# 1115         1.0
# 1116         1.0
# 1117         1.0
# 1118         1.0
# 1119         1.0
#
# [1120 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENOMIC SEX            1120 non-null   object
#  1   AGE                    1120 non-null   int32
#  2   BLOOD_TYPE             1120 non-null   object
#  3   NUMBER_OF_SIBLINGS     1120 non-null   float64
#  4   PARENT_ALIVE           1120 non-null   int64
#  5   SMOKING_STATUS         1120 non-null   int64
#  6   DAILY_CIGARETTES       1120 non-null   float64
#  7   YELLOW_SKIN            1120 non-null   int64
#  8   ANXIETY                1120 non-null   int64
#  9   PEER_PRESSURE          1120 non-null   int64
#  10  COPD_DIAGNOSES         1120 non-null   float64
#  11  FATIGUE                1120 non-null   float64
#  12  ALLERGY                1120 non-null   int64
#  13  WHEEZING               1120 non-null   float64
# ...

# %% [markdown]
# # Relationship between the asthma disease with affecting parameter.

# %%
df.corr()
# Out:
#                        GENOMIC SEX       AGE  BLOOD_TYPE  NUMBER_OF_SIBLINGS  \
# GENOMIC SEX               1.000000  0.004071   -0.002821            0.024889
# AGE                       0.004071  1.000000    0.015127            0.007564
# BLOOD_TYPE               -0.002821  0.015127    1.000000           -0.007705
# NUMBER_OF_SIBLINGS        0.024889  0.007564   -0.007705            1.000000
# PARENT_ALIVE             -0.000693  0.031647    0.024136           -0.032358
# SMOKING_STATUS            0.039998 -0.026666   -0.000637            0.030272
# DAILY_CIGARETTES          0.031364  0.038004   -0.017372           -0.014146
# YELLOW_SKIN              -0.173816 -0.016199   -0.012009            0.028097
# ANXIETY                  -0.095588 -0.008262    0.047799            0.023897
# PEER_PRESSURE            -0.204657  0.045609    0.001386            0.026780
# COPD_DIAGNOSES           -0.180548 -0.011810   -0.004113            0.036721
# ...

# %%
df1=df.to_csv("Pre_Lungcancer")
